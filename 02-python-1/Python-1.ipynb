# %% [markdown]
# # Python 1 - Introduction to Python
#
# ## Objectives
#
# By the end of this first session you should be able to do the following using Python.
#
# * Have become accustomed to IPython notebook
# * Print all the things
# * Use Basic Operations
# * Use string formatting
# * Utilise lists and dictionaries
# * Be able to iterate over said lists
#
# ## IPython Notebook
#
# IPython notebook is a web based interactive computational environment with code, text, mathematics, plot and exectution all in the same place. Its how we'll be doing the whole course, though we wouldn't use it for more script based programming, for that we suggest you use [Spyder](https://pythonhosted.org/spyder/) or your pet text editor.
#
# Some IPython notebook commands to help you through this:
#
# * crtl + enter - Run Cell
# * B - insert cell below when the whole cell is selected
# * esc - moves from the 'text box' to select the cell
# * enter - moves you back in
#
# ## Basic Operations
#
# A great deal of the operations in Python are simply transferable from other languages. But lets go over them anyway.
#
# ### Printing
#
# Print is not a function in Python 2, so literally a print and what you want to print will do in most cases.

# %% [markdown]
# Notice that `a/b` doesn't work. The usual rules with dividing variable types apply. In order to make it work properly you need to make `a` a float.

# %% [markdown]
# We have a few other variable types too.
# * Integer
# * Complex
# * String.

# %% [markdown]
# <div style='background:#B1E0A8; padding:10px 10px 10px 10px;'>
# <h2>Challenge 1</h2>
# <ol>
#   <li>Catch up to this point and write a line of code converting a temperature in Fahrenheit to Celsius.</li>
# </ol>
# </div>

# %% [markdown]
# Strings in quote marks e.g. `"helloworld"`. You can also add strings together.

# %% [markdown]
# You can also use some shiny formatting tricks with .format().

# %% [markdown]
# <div style='background:#B1E0A8; padding:10px 10px 10px 10px;'>
# <h2>Challenge 2</h2>
# <ol>
#   <li>Use the previous example of temperature converting and use formatting to produce me a neater output.</li>
# </ol>
# </div>

# %% [markdown]
# ###Comments
# As an aside, comments use `#` and you can block comment using """ """.

# %% [markdown]
# ##Lists
# Lists are an immensely powerful part of the Python toolbox.
# A list can contain anything: strings, floats, complex numbers *etc*. Lists are iterable objects. Denoted by square brackets, empty lists can be denoted by `alist = []`. Python begins lists with element 0, so `alist[0]` gives you the first element.

# %% [markdown]
# You can also list-ise a string so we can turn `hello world` into a list containing the individual letters within it.

# %% [markdown]
# Then we can use append to stick some more stuff on the end. And we can find the first instance of something with index.

# %% [markdown]
# We can also sort our lists using sort().

# %% [markdown]
# We can also make lists of lists, extremely useful when we start processing and holding lots of data.

# %% [markdown]
# Then you can call elements of each list by indexing them separately. A `[:]` will call all elements of a list.

# %% [markdown]
# <div style='background:#B1E0A8; padding:10px 10px 10px 10px;'>
# <h2>Challenge 3</h2>
# <ol>
#   <li>Produce a list of lists, one list containing some places and the other temperatures.</li>
# </ol>
# </div>

# %% [markdown]
# ###Dictionaries
# Finally we also have dictionaries. Dictionaries are an unordered set of key and value pairs. An empty dictionary is denoted by adict = {}. We can then extract information from it.

# %% [markdown]
# If the keys are strings then you can use the dict method `dict = (some stuff)`.

# %% [markdown]
# ##Iterations
# Essential for efficient programming, `for` and `while` loops are an integral part of Python (and for that matter all languages). So lets go over the syntax. For loops take the form:

# %% [markdown]
# Indent is crucial in Python. For blocks like For, While and If, the block is defined by the indent *i.e.,* returning to the left margin ends the block.
#
# We can also iterate over a list. Useful as we the don't have to define our upper boundary when setting up the loop.

# %% [markdown]
# While will loop continously until a condition is met.Use a `for` loop to print out the pairs of places and temperatures you saw earier.

# %% [markdown]
# A `while` will loop continuously until a condition is met.

# %% [markdown]
# We can also end this using an If statement. Logic commands in Python are:
#
# * == exactly equal
# * != not equal
# * \>(=) less than (equal to)
# * <(=) more than (equal to)

# %% [markdown]
# There are a couple of things to notice in the above block of code. The first is the `while True` continues the loop until it a condition is fulfilled within the loop, which in this case is by an `if` statement.

# %% [markdown]
# <div style='background:#B1E0A8; padding:10px 10px 10px 10px;'>
# <h2>Challenge 4</h2>
# <ol>
#   <li>You're now going to build a pin check. Write some code which reads in a 4 digit number (however you want to do this) and the checks to see whether it matches the preset one (you will have to define the pin to want to check against before executing the loop).
#
# You will also need to know that `raw_input()` takes in a string.
#
# </li>
# </ol>
# </div>
